# %%
# import lib
import pandas as pd
import sklearn as skl
import matplotlib.pyplot as plt

# %%
# read the dataset
df = pd.read_excel("./datamaster.xlsx", sheet_name="all")
# Show dataset
df
# Out:
#       No                   Provinsi  Luas_Areal_2014  Produktiv_2014  \
# 0    1.0                       Aceh     1.016501e+05           683.0
# 1    2.0             Sumatera Utara     6.563900e+04           740.0
# 2    3.0             Sumatera Barat     1.569977e+05           816.0
# 3    4.0                       Riau     7.156440e+03           695.0
# 4    5.0             Kepulauan Riau     5.000000e+00           333.0
# 5    6.0                      Jambi     2.220000e+03           583.0
# 6    7.0           Sumatera Selatan     1.045469e+04           791.0
# 7    8.0  Kepulauan Bangka Belitung     7.098800e+02           477.0
# 8    9.0                   Bengkulu     1.342100e+04           728.0
# 9   10.0                    Lampung     7.203200e+04           801.0
# 10  11.0                DKI Jakarta              NaN             NaN
# 11  12.0                 Jawa Barat     9.546130e+03           514.0
# 12  13.0                     Banten     7.582309e+03           708.0
# ...

# %%
prod14 = df.iloc[34, 4]
print(prod14)
# Out:
# 728413.6798807323

# %%
prod15 = df.iloc[34, 14]
print(prod15)
# Out:
# 593327.0

# %%
prod16 = df.iloc[34, 24]
print(prod16)
# Out:
# 654799.0

# %%
prod17 = df.iloc[34, 34]
print(prod17)
# Out:
# 590683.6929453395

# %%
prod18 = df.iloc[34, 44]
print(prod18)
# Out:
# 767280.0504128013

# %%
prod19 = df.iloc[34, 54]
print(prod19)
# Out:
# 783979.0

# %%
prod20 = df.iloc[34, 64]
print(prod20)
# Out:
# 720658.0

# %%
prod21 = df.iloc[34, 74]
print(prod21)
# Out:
# 736637.0

# %%
# grafik garis dari prod14 dan prod15
plt.plot(["prod14", "prod15", "prod16", "prod17", "prod18", "prod19", "prod20", "prod21"], [prod14, prod15, prod16, prod17, prod18, prod19, prod20, prod21])
plt.show()
