# %%
# import lib
import pandas as pd

# %%
# read the dataset
df = pd.read_excel("./datamaster.xlsx", sheet_name="2014")
# Show dataset
df
# Out:
#       No                   Provinsi  Luas_Areal_2014  Produktiv_2014  \
# 0    1.0                       Aceh     1.016501e+05           683.0
# 1    2.0             Sumatera Utara     6.563900e+04           740.0
# 2    3.0             Sumatera Barat     1.569977e+05           816.0
# 3    4.0                       Riau     7.156440e+03           695.0
# 4    5.0             Kepulauan Riau     5.000000e+00           333.0
# 5    6.0                      Jambi     2.220000e+03           583.0
# 6    7.0           Sumatera Selatan     1.045469e+04           791.0
# 7    8.0  Kepulauan Bangka Belitung     7.098800e+02           477.0
# 8    9.0                   Bengkulu     1.342100e+04           728.0
# 9   10.0                    Lampung     7.203200e+04           801.0
# 10  11.0                DKI Jakarta              NaN             NaN
# 11  12.0                 Jawa Barat     9.546130e+03           514.0
# 12  13.0                     Banten     7.582309e+03           708.0
# ...

# %%
# select data only Aceh
df_aceh = df[df["Provinsi"] == "Aceh"]

# Show dataset
df_aceh
# Out:
#     No Provinsi  Luas_Areal_2014  Produktiv_2014  Produksi_2014  \
# 0  1.0     Aceh        101650.06           683.0      28015.088
#
#    Jumlah_Petani  Areal_Perkebunan_Rakyat  Areal_Perkebunan_Pemerintah  \
# 0       128989.0                 101576.0                          NaN
#
#    Areal_Perkebunan_Swasta  Tanaman_Imature  Tanaman_Mature  Tanaman_Damage
# 0                     74.0          32199.0         41040.0         28411.0

# %%
# select data only Maluku
df_maluku = df[df["Provinsi"] == "Maluku"]

# Show dataset
df_maluku
# Out:
#       No Provinsi  Luas_Areal_2014  Produktiv_2014  Produksi_2014  \
# 30  31.0   Maluku         30134.47           594.0    9680.326733
#
#     Jumlah_Petani  Areal_Perkebunan_Rakyat  Areal_Perkebunan_Pemerintah  \
# 30        34075.0                  26878.0                       2053.0
#
#     Areal_Perkebunan_Swasta  Tanaman_Imature  Tanaman_Mature  Tanaman_Damage
# 30                   1203.0           6024.0         16294.0          7817.0
